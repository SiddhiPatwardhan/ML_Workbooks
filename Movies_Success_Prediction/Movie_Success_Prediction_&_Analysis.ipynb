# %%
# importing all libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movies = pd.read_csv('/content/tmdb_5000_movies.csv')
credits = pd.read_csv('/content/tmdb_5000_credits.csv')

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
movies.shape
# Out:
# (4803, 20)

# %%
credits.shape
# Out:
# (4803, 4)

# %%
movies= movies.merge(credits,on='title')

# %%
movies.shape
# Out:
# (4809, 23)

# %% [markdown]
# ### List of dictionaries
# > genres
#
# > keywords
#
# > production_companies
#
# > production_countries
#
# > spoken_languages
#
# > cast
#
# > crew

# %%
movies.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'movie_id', 'cast', 'crew'],
#       dtype='object')

# %%
movies.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3096
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# movie_id                   0
# cast                       0
# crew                       0
# dtype: int64

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies.status.value_counts()
# Out:
# status
# Released           4801
# Rumored               5
# Post Production       3
# Name: count, dtype: int64

# %%
movies.original_language.value_counts()
# Out:
# original_language
# en    4510
# fr      70
# es      32
# zh      27
# de      27
# hi      19
# ja      16
# it      14
# ko      12
# cn      12
# ru      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# id       2
# cs       2
# ta       2
# ro       2
# ar       2
# te       1
# hu       1
# xx       1
# af       1
# is       1
# tr       1
# vi       1
# pl       1
# nb       1
# ky       1
# no       1
# sl       1
# ps       1
# el       1
# Name: count, dtype: int64

# %%
movies = movies.drop(['homepage', 'overview', 'tagline', 'status'], axis=1)

# %%
movies.isnull().sum()
# Out:
# budget                  0
# genres                  0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            1
# revenue                 0
# runtime                 2
# spoken_languages        0
# title                   0
# vote_average            0
# vote_count              0
# movie_id                0
# cast                    0
# crew                    0
# dtype: int64

# %%
movies.dropna(inplace = True)

# %%
movies.shape
# Out:
# (4806, 19)

# %%
movies.isnull().sum()
# Out:
# budget                  0
# genres                  0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# title                   0
# vote_average            0
# vote_count              0
# movie_id                0
# cast                    0
# crew                    0
# dtype: int64

# %%
# Checking the duplicates
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
def convert(obj):
    L =[]
    for i in ast.literal_eval(obj):
        i['name']
        L.append(i['name'])
    return L

# %%
import ast
movies['genres'] = movies['genres'].apply(convert)
movies.head()
# Out:
#       budget                                         genres      id  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1  300000000                   [Adventure, Fantasy, Action]     285
# 2  245000000                     [Action, Adventure, Crime]  206647
# 3  250000000               [Action, Crime, Drama, Thriller]   49026
# 4  260000000           [Action, Adventure, Science Fiction]   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  popularity  \
# 0                                    Avatar  150.437577
# ...

# %%
movies['keywords'] = movies['keywords'].apply(convert)
movies.head()
# Out:
#       budget                                         genres      id  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1  300000000                   [Adventure, Fantasy, Action]     285
# 2  245000000                     [Action, Adventure, Crime]  206647
# 3  250000000               [Action, Crime, Drama, Thriller]   49026
# 4  260000000           [Action, Adventure, Science Fiction]   49529
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# 2  [spy, based on novel, secret agent, sequel, mi...                en
# 3  [dc comics, crime fighter, terrorist, secret i...                en
# 4  [based on novel, mars, medallion, space travel...                en
#
#                              original_title  popularity  \
# 0                                    Avatar  150.437577
# ...

# %%
movies['production_companies'] = movies['production_companies'].apply(convert)
movies.head()
# Out:
#       budget                                         genres      id  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1  300000000                   [Adventure, Fantasy, Action]     285
# 2  245000000                     [Action, Adventure, Crime]  206647
# 3  250000000               [Action, Crime, Drama, Thriller]   49026
# 4  260000000           [Action, Adventure, Science Fiction]   49529
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# 2  [spy, based on novel, secret agent, sequel, mi...                en
# 3  [dc comics, crime fighter, terrorist, secret i...                en
# 4  [based on novel, mars, medallion, space travel...                en
#
#                              original_title  popularity  \
# 0                                    Avatar  150.437577
# ...

# %%
movies['production_countries'] = movies['production_countries'].apply(convert)
movies.head()
# Out:
#       budget                                         genres      id  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1  300000000                   [Adventure, Fantasy, Action]     285
# 2  245000000                     [Action, Adventure, Crime]  206647
# 3  250000000               [Action, Crime, Drama, Thriller]   49026
# 4  260000000           [Action, Adventure, Science Fiction]   49529
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# 2  [spy, based on novel, secret agent, sequel, mi...                en
# 3  [dc comics, crime fighter, terrorist, secret i...                en
# 4  [based on novel, mars, medallion, space travel...                en
#
#                              original_title  popularity  \
# 0                                    Avatar  150.437577
# ...

# %%
movies['spoken_languages'] = movies['spoken_languages'].apply(convert)
movies.head()
# Out:
#       budget                                         genres      id  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1  300000000                   [Adventure, Fantasy, Action]     285
# 2  245000000                     [Action, Adventure, Crime]  206647
# 3  250000000               [Action, Crime, Drama, Thriller]   49026
# 4  260000000           [Action, Adventure, Science Fiction]   49529
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# 2  [spy, based on novel, secret agent, sequel, mi...                en
# 3  [dc comics, crime fighter, terrorist, secret i...                en
# 4  [based on novel, mars, medallion, space travel...                en
#
#                              original_title  popularity  \
# 0                                    Avatar  150.437577
# ...

# %%
def convert3(obj):
    L = []
    counter = 0
    for i in ast.literal_eval(obj):
        if counter < 3:
            L.append(i['name'])
        counter+=1
    return L

# %%
movies['cast'] = movies['cast'].apply(convert3)
movies.head()
# Out:
#       budget                                         genres      id  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1  300000000                   [Adventure, Fantasy, Action]     285
# 2  245000000                     [Action, Adventure, Crime]  206647
# 3  250000000               [Action, Crime, Drama, Thriller]   49026
# 4  260000000           [Action, Adventure, Science Fiction]   49529
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# 2  [spy, based on novel, secret agent, sequel, mi...                en
# 3  [dc comics, crime fighter, terrorist, secret i...                en
# 4  [based on novel, mars, medallion, space travel...                en
#
#                              original_title  popularity  \
# 0                                    Avatar  150.437577
# ...

# %%
def fetch_director(obj):
    L = []
    for i in ast.literal_eval(obj):
        if i['job'] == 'Director':
            L.append(i['name'])
    return L

# %%
movies['crew'] = movies['crew'].apply(fetch_director)
movies.head()
# Out:
#       budget                                         genres      id  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1  300000000                   [Adventure, Fantasy, Action]     285
# 2  245000000                     [Action, Adventure, Crime]  206647
# 3  250000000               [Action, Crime, Drama, Thriller]   49026
# 4  260000000           [Action, Adventure, Science Fiction]   49529
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# 2  [spy, based on novel, secret agent, sequel, mi...                en
# 3  [dc comics, crime fighter, terrorist, secret i...                en
# 4  [based on novel, mars, medallion, space travel...                en
#
#                              original_title  popularity  \
# 0                                    Avatar  150.437577
# ...

# %%
# remove the spaces -> bcoz it may lead to confusions in model
# Apply this transformation
movies['genres'] = movies['genres'].apply(lambda x:[i.replace(" ","")for i in x])
movies['keywords'] = movies['keywords'].apply(lambda x:[i.replace(" ","")for i in x])
movies['production_companies'] = movies['production_companies'].apply(lambda x:[i.replace(" ","")for i in x])
movies['production_countries'] = movies['production_countries'].apply(lambda x:[i.replace(" ","")for i in x])
movies['spoken_languages'] = movies['spoken_languages'].apply(lambda x:[i.replace(" ","")for i in x])
movies['cast'] = movies['cast'].apply(lambda x:[i.replace(" ","")for i in x])
movies['crew'] = movies['crew'].apply(lambda x:[i.replace(" ","")for i in x])

# %%
movies.head()
# Out:
#       budget                                        genres      id  \
# 0  237000000  [Action, Adventure, Fantasy, ScienceFiction]   19995
# 1  300000000                  [Adventure, Fantasy, Action]     285
# 2  245000000                    [Action, Adventure, Crime]  206647
# 3  250000000              [Action, Crime, Drama, Thriller]   49026
# 4  260000000           [Action, Adventure, ScienceFiction]   49529
#
#                                             keywords original_language  \
# 0  [cultureclash, future, spacewar, spacecolony, ...                en
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...                en
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...                en
# 3  [dccomics, crimefighter, terrorist, secretiden...                en
# 4  [basedonnovel, mars, medallion, spacetravel, p...                en
#
#                              original_title  popularity  \
# 0                                    Avatar  150.437577
# ...

# %%
movies.to_csv('movies.csv',index=False)

# %%
# First, clean 0 or missing values
movies = movies[(movies['budget'] > 1000000) & (movies['revenue'] > 0)]

# %%
movies.shape
# Out:
# (3090, 19)

# %%
# Label: Hit (1) if profit margin ≥ 20%
movies['success'] = (movies['revenue'] > movies['budget'] * 1.2).astype(int)
# Out:
# <ipython-input-94-c52d2ffe55e4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['success'] = (movies['revenue'] > movies['budget'] * 1.2).astype(int)

# %%
movies.head()
# Out:
#       budget                                        genres      id  \
# 0  237000000  [Action, Adventure, Fantasy, ScienceFiction]   19995
# 1  300000000                  [Adventure, Fantasy, Action]     285
# 2  245000000                    [Action, Adventure, Crime]  206647
# 3  250000000              [Action, Crime, Drama, Thriller]   49026
# 4  260000000           [Action, Adventure, ScienceFiction]   49529
#
#                                             keywords original_language  \
# 0  [cultureclash, future, spacewar, spacecolony, ...                en
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...                en
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...                en
# 3  [dccomics, crimefighter, terrorist, secretiden...                en
# 4  [basedonnovel, mars, medallion, spacetravel, p...                en
#
#                              original_title  popularity  \
# 0                                    Avatar  150.437577
# ...

# %%
movies.success.value_counts()
# Out:
# success
# 1    2182
# 0     908
# Name: count, dtype: int64

# %%
movies.columns
# Out:
# Index(['budget', 'genres', 'id', 'keywords', 'original_language',
#        'original_title', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'title', 'vote_average', 'vote_count', 'movie_id',
#        'cast', 'crew', 'success'],
#       dtype='object')

# %%
movies.head(1)
# Out:
#       budget                                        genres     id  \
# 0  237000000  [Action, Adventure, Fantasy, ScienceFiction]  19995
#
#                                             keywords original_language  \
# 0  [cultureclash, future, spacewar, spacecolony, ...                en
#
#   original_title  popularity  \
# 0         Avatar  150.437577
#
#                                 production_companies  \
# 0  [IngeniousFilmPartners, TwentiethCenturyFoxFil...
#
#                      production_countries release_date     revenue  runtime  \
# 0  [UnitedStatesofAmerica, UnitedKingdom]   2009-12-10  2787965087    162.0
#
#      spoken_languages   title  vote_average  vote_count  movie_id  \
# 0  [English, Español]  Avatar           7.2       11800     19995
#
#                                             cast            crew  success
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]  [JamesCameron]        1

# %%
movies.to_csv('movies_analysis.csv',index=False)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3090 entries, 0 to 4764
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                3090 non-null   int64
#  1   genres                3090 non-null   object
#  2   id                    3090 non-null   int64
#  3   keywords              3090 non-null   object
#  4   original_language     3090 non-null   object
#  5   original_title        3090 non-null   object
#  6   popularity            3090 non-null   float64
#  7   production_companies  3090 non-null   object
#  8   production_countries  3090 non-null   object
#  9   release_date          3090 non-null   object
#  10  revenue               3090 non-null   int64
#  11  runtime               3090 non-null   float64
#  12  spoken_languages      3090 non-null   object
#  13  title                 3090 non-null   object
#  14  vote_average          3090 non-null   float64
# ...

# %%
# Convert release_date to datetime
movies['release_date'] = pd.to_datetime(movies['release_date'], errors='coerce')
movies['year'] = movies['release_date'].dt.year
# Out:
# <ipython-input-104-f94b57cbd37a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['release_date'] = pd.to_datetime(movies['release_date'], errors='coerce')
# <ipython-input-104-f94b57cbd37a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['year'] = movies['release_date'].dt.year

# %%
movies.head()
# Out:
#       budget                                        genres      id  \
# 0  237000000  [Action, Adventure, Fantasy, ScienceFiction]   19995
# 1  300000000                  [Adventure, Fantasy, Action]     285
# 2  245000000                    [Action, Adventure, Crime]  206647
# 3  250000000              [Action, Crime, Drama, Thriller]   49026
# 4  260000000           [Action, Adventure, ScienceFiction]   49529
#
#                                             keywords original_language  \
# 0  [cultureclash, future, spacewar, spacecolony, ...                en
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...                en
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...                en
# 3  [dccomics, crimefighter, terrorist, secretiden...                en
# 4  [basedonnovel, mars, medallion, spacetravel, p...                en
#
#                              original_title  popularity  \
# 0                                    Avatar  150.437577
# ...

# %%
from collections import Counter
# ---- 1. Top 10 Genres ----
genre_count = Counter([genre for genres in movies['genres'] for genre in genres])
top_genres = dict(genre_count.most_common(10))

plt.figure(figsize=(10, 6))
plt.bar(top_genres.keys(), top_genres.values(), color='skyblue')
plt.title("Top 10 Genres")
plt.xticks(rotation=45)
plt.ylabel("Number of Movies")
plt.show()

# %%
# ---- 2. Revenue vs Budget ----
plt.figure(figsize=(8, 6))
sns.scatterplot(data=movies, x='budget', y='revenue', hue='success', palette='coolwarm')
plt.title("Budget vs Revenue (Color: Success)")
plt.show()

# %%
# ---- 3. Hit vs Flop Count ----
plt.figure(figsize=(6, 5))
sns.countplot(x='success', data=movies)
plt.xticks([0, 1], ['Flop', 'Hit'])
plt.title("Hit vs Flop Distribution")
plt.show()

# %%
# ---- 4. Average Revenue by Genre ----
df_exploded = movies.explode('genres')
df_exploded['genres'] = df_exploded['genres'].apply(lambda x: x.strip("[]").replace("'", "").replace('"', '') if isinstance(x, str) else x)
avg_revenue = df_exploded.groupby('genres')['revenue'].mean().sort_values(ascending=False).head(10)

plt.figure(figsize=(10, 6))
avg_revenue.plot(kind='bar', color='orange')
plt.title("Top 10 Genres by Avg Revenue")
plt.ylabel("Average Revenue")
plt.xticks(rotation=45)
plt.show()

# %%
# ---- 5. Top 10 Actors ----
actor_count = Counter([actor for cast in movies['cast'] for actor in cast])
top_actors = dict(actor_count.most_common(10))

plt.figure(figsize=(10, 6))
plt.bar(top_actors.keys(), top_actors.values(), color='purple')
plt.title("Top 10 Most Frequent Actors")
plt.xticks(rotation=45)
plt.ylabel("Number of Movies")
plt.show()

# %%
# ---- 6. Hits Over the Years ----
hits_per_year = movies[movies['success'] == 1].groupby('year').size()

plt.figure(figsize=(10, 6))
hits_per_year.plot(marker='o')
plt.title("Number of Hit Movies Per Year")
plt.xlabel("Year")
plt.ylabel("Hits")
plt.grid(True)
plt.show()
